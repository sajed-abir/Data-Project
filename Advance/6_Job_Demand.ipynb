# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_us = df[df['job_country'] == 'United States'].copy()

# %%
df_us['job_posted_month'] = df_us['job_posted_date'].dt.strftime('%B')
df_us
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 3              Data Engineer
# 5              Data Engineer
# 6       Senior Data Engineer
# 9             Data Scientist
# ...                      ...
# 785673        Data Scientist
# 785685          Data Analyst
# 785692        Data Scientist
# 785703          Data Analyst
# 785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 5                                       GCP Data Engineer          Anywhere
# 6                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# 9                                       Data Scientist II          Anywhere
# ...                                                   ...               ...
# ...

# %%
df_us_pivot=df_us.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_us_pivot.reset_index(inplace = True)
df_us_pivot['month_no'] = pd.to_datetime(df_us_pivot['job_posted_month'], format='%B').dt.month

# %%
df_us_pivot.sort_values('month_no', inplace=True)
df_us_pivot.set_index('job_posted_month', inplace=True)
df_us_pivot.drop(columns='month_no', inplace=True)

# %%
df_us_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_us_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_us['job_title_short'].value_counts().head(3)
top_3=top_3.index.tolist()

# %%
df_us_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data jobs in the US')
plt.xlabel('Month')
plt.ylabel('Job Count')
plt.legend()
plt.show()

# %% [markdown]
# ----> For BANGLADESH

# %%
df_bd = df[df['job_country'] == 'Bangladesh'].copy()

# %%
df_bd['job_posted_month'] = df_bd['job_posted_date'].dt.strftime('%B')
df_bd

# %%
df_bd_pivot=df_us.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_bd_pivot.reset_index(inplace = True)
df_bd_pivot['month_no'] = pd.to_datetime(df_bd_pivot['job_posted_month'], format='%B').dt.month

# %%
df_bd_pivot.sort_values('month_no', inplace=True)
df_bd_pivot.set_index('job_posted_month', inplace=True)
df_bd_pivot.drop(columns='month_no', inplace=True)

# %%
df_bd_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        4.0             1.0           7.0
# February                       4.0             NaN           3.0
# March                          1.0             NaN           6.0
# April                          1.0             NaN           2.0
# May                            6.0             NaN           3.0
# June                           NaN             NaN           3.0
# July                           2.0             NaN           6.0
# August                         2.0             2.0           2.0
# September                      4.0             NaN           7.0
# October                        5.0             NaN          10.0
# November                       8.0             1.0           9.0
# December                       4.0             NaN           6.0
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_bd_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_bd['job_title_short'].value_counts().head(3)
top_3=top_3.index.tolist()

# %%
df_bd_pivot[top_3].plot(kind='line')
plt.title('Monthly Job Postings for Top Data jobs in Bangladesh')
plt.xlabel('Month')
plt.ylabel('Job Count')
plt.legend()
plt.show()
